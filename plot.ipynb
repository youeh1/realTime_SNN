# %%
using Plots
using DelimitedFiles

# %%
f = readdlm("data.txt",Float64)
# Out:
# 9999×1 Array{Float64,2}:
#  -72.0
#  -71.9286
#  -71.8578
#  -71.7874
#  -71.7176
#  -71.6482
#  -71.5794
#  -71.5111
#  -71.4432
#  -71.3759
#  -71.309
#  -71.2426
#  -71.1768
#    ⋮
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426
#  -62.1426

# %%
plot(1:length(f),f)
